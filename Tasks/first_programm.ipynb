# %% [markdown]
# <a href="https://colab.research.google.com/github/hinaa2ss/University/blob/main/Tasks/first_programm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("heeeeey")
# Out:
# heeeeey
